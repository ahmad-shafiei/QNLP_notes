# %% [markdown]
# ## New Simple QNLP Project

# %% [markdown]
# ## Main Project

# %%
from preprocess import normalize_text, tokenize_text, \
                        merge_compound_verbs,label_roles #, detect_object_with_ra
txt1 = ' ?!!احمد غذا خوشمزه را خورد '
txt2 = 'رضا برنامه را ران گرفت'
txt2 = "مرد برنامه مناسب را اشکالزدایی کرد"
txt1 = normalize_text(txt1)
txt2 = normalize_text(txt2)

tokens1= (tokenize_text(txt2))
tokens2= (tokenize_text(txt2))

print(tokenize_text(txt1))
print(merge_compound_verbs(tokens2))

print(label_roles(tokens1))
# Out:
# ['احمد', 'غذا', 'خوشمزه', 'را', 'خورد']
# ['مرد', 'برنامه', 'مناسب', 'را', 'اشکالزدایی کرد']
# [('مرد', 'subj'), ('برنامه', 'obj'), ('مناسب', 'adj'), ('را', 'other'), ('اشکالزدایی کرد', 'verb')]

# %%
from persian_cat_parser import PersianCatParser
sent1 = "مرد غذا  را پخت"
# sent1 = "مرد ماهر نرم افزار مناسب را اجرا کرد"
sent1 = "مرد برنامه را اشکالزدایی کرد"
sent1 = "شخص نرم افزار مناسب را اشکال زدایی کرد"
parser = PersianCatParser()

diagram = parser.sentence2diagram(sent1)
diagram.draw()

# %%
from hazm import POSTagger
tagger = POSTagger(model='resources/pos_tagger.model')
print(tagger.tag(['مرد', 'غذا', 'را', 'پخت']))
# Out:
# [('مرد', 'NOUN,EZ'), ('غذا', 'NOUN'), ('را', 'ADP'), ('پخت', 'VERB')]

# %% [markdown]
# ### test with new Parser

# %%
# Hazm-based preprocessing
from preprocess_hazm import process_sentence

# جمله تست 1: فاعل + صفت + مفعول + صفت + فعل
sent1 = "مرد غذای خوشمزه را پخت"
labeled1 = process_sentence(sent1)
print("جمله 1:", sent1)
print("نتیجه:", labeled1)
print("\n")

# جمله تست 2: فاعل + صفت + مفعول + فعل
sent2 = "شخص ماهر غذای خوشمزه را پخت"
labeled2 = process_sentence(sent2)
print("جمله 2:", sent2)
print("نتیجه:", labeled2)
print("\n")

# جمله تست 3: فاعل + مفعول مرکب + فعل مرکب
sent3 = "مرد نرم افزار را اجرا کرد"
labeled3 = process_sentence(sent3)
print("جمله 3:", sent3)
print("نتیجه:", labeled3)
# Out:
# جمله 1: مرد غذای خوشمزه را پخت
# نتیجه: [('مرد', 'subj'), ('غذای', 'obj'), ('خوشمزه', 'adj'), ('را', 'ra'), ('پخت', 'verb')]
#
#
# جمله 2: شخص ماهر غذای خوشمزه را پخت
# نتیجه: [('شخص', 'subj'), ('ماهر', 'adj'), ('غذای', 'obj'), ('خوشمزه', 'adj'), ('را', 'ra'), ('پخت', 'verb')]
#
#
# جمله 3: مرد نرم افزار را اجرا کرد
# نتیجه: [('مرد', 'subj'), ('نرم\u200cافزار', 'obj'), ('را', 'ra'), ('اجرا کرد', 'verb')]

# %%
from hazm import DependencyParser, POSTagger, word_tokenize

tagger = POSTagger(model='resources/pos_tagger.model')

sentence = "من به مدرسه رفتم ."
tokens = word_tokenize(sentence)
tagged = tagger.tag(tokens)

print("Tagged:", tagged)
# Out:
# Tagged: [('من', 'PRON'), ('به', 'ADP'), ('مدرسه', 'NOUN'), ('رفتم', 'VERB'), ('.', 'PUNCT')]

# %%
from persian_cat_parser import PersianCatParser
sent1 = "مرد غذا  را پخت"
sent1 = "مرد ماهر نرم افزار مناسب را اجرا کرد"
# sent1 = "مرد برنامه را اشکال زدایی کرد"

parser = PersianCatParser()
sent1 = "شخص نرم افزار مناسب را اشکال زدایی کرد"
diagram = parser.sentence2diagram(sent1)
diagram.draw()

# %%
from persian_cat_parser import PersianCatParser, fix_persian
from preprocess_hazm import process_sentence

sentence = "شخص برنامه را اشکال زدایی کرد"
labeled = process_sentence(sentence)
print("Labeled tokens (token, role):")
for tok, role in labeled:
    print(f"{tok} -> {role}")

parser = PersianCatParser(verbose=True)
diagram = parser.sentence2diagram(sentence)

# تصویری نمودار
diagram.draw()   # اگر محیط گرافیکی داری

# بازرسی متنیِ توکن‌ها و نقش‌ها (حالا بدون خطا)
print("\nTokens in diagram (display_text -> role):")
for text, role in diagram.word_role_pairs:
    print(f"{text} -> {role}")
# Out:
# Labeled tokens (token, role):
# شخص -> subj
# برنامه -> obj
# را -> ra
# اشکال زدایی کرد -> verb
# Tokens in diagram (display_text -> role):
# شخص -> subj
# برنامه -> obj
# را -> ra
# اشکال زدایی کرد -> verb

# %% [markdown]
# مشکل در فرم داده های ورودی هست.
#     چرا که همان طور که در زیر مشخص است
# برای یک جمله که به صورت دستی به مدل داده می شود
# برنامه عملکرد درستی دارد!

# %% [markdown]
# ## the main persian project for ML learning

# %%
from persian_cat_parser import PersianCatParser
from preprocess_hazm import read_data

train_labels, train_data = read_data("datasets/mc_train_data.txt")   # label [t 1-t]
dev_labels, dev_data     = read_data("datasets/mc_dev_data.txt")
test_labels, test_data   = read_data("datasets/mc_test_data.txt")

parser = PersianCatParser(verbose=True)
# train_data = ["زن غذای خوشمزه را پخت."]     # test with a sentence with and without punctubations!
raw_train_diagrams = parser.sentences2diagrams(train_data)
raw_dev_diagrams   = parser.sentences2diagrams(dev_data)
raw_test_diagrams  = parser.sentences2diagrams(test_data)

# %%
# انتخاب یک جمله و نمایش ان
idx = 17 
sent = train_data[idx]
# sent = dev_data[idx]
sent = test_data[idx]
# sent = "مرد غذای خوشمزه را پخت"

d = parser.sentence2diagram(sent)
print("Sentence:", sent)
# print("Diagram:", d)
d.draw()
# Out:
# Sentence: مرد نرم افزار را اشکال زدایی کرد.

# %% [markdown]
# ### Create Diagram

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# معرفی فونت فارسی
rcParams['font.family'] = 'Tahoma'   # یا مثلاً 'Vazirmatn' اگر نصب باشه
raw_train_diagrams[36].draw(size='18')
plt.show()

# %%
from persian_cat_parser import PersianCatParser
from preprocess import read_data

train_labels, train_data = read_data("datasets/mc_train_data.txt")   # label [t 1-t]
parser = PersianCatParser(verbose=True)
raw_train_diagrams = parser.sentences2diagrams(train_data)
idx = 39 
sent = train_data[idx]
d = parser.sentence2diagram(sent)
print("Sentence:", sent)
d.draw()
# Out:
# Sentence: زن نرم افزار را اجرا کرد.

# %% [markdown]
# ### Remove the Cups

# %% [markdown]
# ### Create Circuits

# %%
from lambeq import RemoveCupsRewriter 

remove_cups = RemoveCupsRewriter()
train_diagrams = [remove_cups(diagram) for diagram in raw_train_diagrams]
dev_diagrams   = [remove_cups(diagram) for diagram in raw_dev_diagrams  ]
test_diagrams  = [remove_cups(diagram) for diagram in raw_test_diagrams ]
# train_diagrams[14].draw()

# %%
from lambeq import IQPAnsatz
from lambeq import AtomicType
from lambeq.backend.grammar import Ty
ansatz = IQPAnsatz({AtomicType.NOUN: 1, AtomicType.SENTENCE: 1, Ty('o'):1}, n_layers=1, n_single_qubit_params=3)
train_circuits = [ansatz(diagram) for diagram in train_diagrams]
dev_circuits   = [ansatz(diagram) for diagram in dev_diagrams  ]
test_circuits  = [ansatz(diagram) for diagram in test_diagrams ]

# %%
# -------------------------------
# Backend and model
# -------------------------------
from lambeq import TketModel
from pytket.extensions.qiskit import AerBackend

backend = AerBackend()
backend_config = {
    'backend': backend,
    'compilation': backend.default_compilation_pass(2),
    'shots': 8192
}
all_circuits = train_circuits + dev_circuits + test_circuits
model = TketModel.from_diagrams(all_circuits, backend_config=backend_config)

# %%
# -------------------------------
# Training setup
# -------------------------------
from lambeq import BinaryCrossEntropyLoss
from lambeq import QuantumTrainer, SPSAOptimizer
import numpy as np

bce = BinaryCrossEntropyLoss()
acc = lambda y_hat, y: np.sum(np.round(y_hat) == y) / len(y) / 2

BATCH_SIZE = 60
EPOCHS = 140

trainer = QuantumTrainer(
    model,
    loss_function=bce,
    epochs=EPOCHS,
    optimizer=SPSAOptimizer,
    optim_hyperparams={'a': 0.05, 'c': 0.06, 'A': 0.01 * EPOCHS},
    evaluate_functions={'acc': acc},
    evaluate_on_train=True,
    verbose='text',
    seed=2,
)

# %%
# -------------------------------
# Prepare datasets
# -------------------------------
from lambeq import Dataset
train_dataset = Dataset(train_circuits, train_labels, batch_size=BATCH_SIZE)
val_dataset   = Dataset(dev_circuits, dev_labels, shuffle=False)

# Train
trainer.fit(train_dataset, val_dataset, log_interval=1)
# Out:
# Epoch 1:    train/loss: 1.2438   valid/loss: 0.7669   train/time: 29.07s   valid/time: 5.63s   train/acc: 0.4366   valid/acc: 0.5833
# Epoch 2:    train/loss: 0.7384   valid/loss: 0.7645   train/time: 27.48s   valid/time: 5.89s   train/acc: 0.5211   valid/acc: 0.5500
# Epoch 3:    train/loss: 2.5701   valid/loss: 1.4218   train/time: 27.62s   valid/time: 5.65s   train/acc: 0.6408   valid/acc: 0.4000
# Epoch 4:    train/loss: 0.7876   valid/loss: 1.3607   train/time: 25.78s   valid/time: 5.23s   train/acc: 0.6761   valid/acc: 0.4000
# Epoch 5:    train/loss: 0.7125   valid/loss: 1.2277   train/time: 25.98s   valid/time: 5.86s   train/acc: 0.5775   valid/acc: 0.4000
# Epoch 6:    train/loss: 0.7287   valid/loss: 1.2161   train/time: 26.03s   valid/time: 5.93s   train/acc: 0.6761   valid/acc: 0.4333
# Epoch 7:    train/loss: 0.6869   valid/loss: 1.0972   train/time: 27.93s   valid/time: 5.90s   train/acc: 0.6056   valid/acc: 0.5333
# Epoch 8:    train/loss: 0.7669   valid/loss: 1.0794   train/time: 29.36s   valid/time: 5.71s   train/acc: 0.5704   valid/acc: 0.4333
# Epoch 9:    train/loss: 0.9147   valid/loss: 1.2226   train/time: 26.80s   valid/time: 6.24s   train/acc: 0.6761   valid/acc: 0.4333
# Epoch 10:   train/loss: 0.6092   valid/loss: 1.2707   train/time: 28.65s   valid/time: 5.65s   train/acc: 0.6620   valid/acc: 0.4000
# Epoch 11:   train/loss: 0.5704   valid/loss: 1.8034   train/time: 28.22s   valid/time: 5.20s   train/acc: 0.7042   valid/acc: 0.4333
# Epoch 12:   train/loss: 0.4826   valid/loss: 1.2062   train/time: 26.13s   valid/time: 5.27s   train/acc: 0.7042   valid/acc: 0.4000
# Epoch 13:   train/loss: 0.5292   valid/loss: 1.1422   train/time: 24.84s   valid/time: 5.72s   train/acc: 0.7113   valid/acc: 0.4000
# Epoch 14:   train/loss: 0.3895   valid/loss: 1.1667   train/time: 25.54s   valid/time: 6.07s   train/acc: 0.7113   valid/acc: 0.4333
# Epoch 15:   train/loss: 0.5125   valid/loss: 1.2132   train/time: 28.24s   valid/time: 6.47s   train/acc: 0.7183   valid/acc: 0.4667
# Epoch 16:   train/loss: 0.5025   valid/loss: 1.3045   train/time: 27.73s   valid/time: 5.71s   train/acc: 0.6831   valid/acc: 0.4333
# Epoch 17:   train/loss: 0.5985   valid/loss: 1.7972   train/time: 28.34s   valid/time: 5.59s   train/acc: 0.7042   valid/acc: 0.4333
# Epoch 18:   train/loss: 0.7589   valid/loss: 2.4070   train/time: 31.29s   valid/time: 6.14s   train/acc: 0.6761   valid/acc: 0.3667
# Epoch 19:   train/loss: 0.5255   valid/loss: 1.8223   train/time: 33.46s   valid/time: 5.51s   train/acc: 0.6761   valid/acc: 0.4333
# Epoch 20:   train/loss: 0.5629   valid/loss: 1.1641   train/time: 33.14s   valid/time: 5.78s   train/acc: 0.6901   valid/acc: 0.3667
# Epoch 21:   train/loss: 0.4792   valid/loss: 1.2043   train/time: 30.99s   valid/time: 6.74s   train/acc: 0.7465   valid/acc: 0.4333
# Epoch 22:   train/loss: 0.6060   valid/loss: 1.1440   train/time: 35.13s   valid/time: 5.72s   train/acc: 0.7183   valid/acc: 0.4333
# Epoch 23:   train/loss: 0.4701   valid/loss: 1.1309   train/time: 28.75s   valid/time: 6.37s   train/acc: 0.7183   valid/acc: 0.4000
# Epoch 24:   train/loss: 0.5458   valid/loss: 1.1400   train/time: 28.80s   valid/time: 5.85s   train/acc: 0.6972   valid/acc: 0.4000
# Epoch 25:   train/loss: 0.5057   valid/loss: 1.1257   train/time: 28.87s   valid/time: 6.07s   train/acc: 0.6901   valid/acc: 0.4333
# Epoch 26:   train/loss: 0.6272   valid/loss: 1.7227   train/time: 28.51s   valid/time: 5.67s   train/acc: 0.6901   valid/acc: 0.3833
# Epoch 27:   train/loss: 0.6284   valid/loss: 1.1494   train/time: 28.31s   valid/time: 5.78s   train/acc: 0.7324   valid/acc: 0.4167
# Epoch 28:   train/loss: 0.5380   valid/loss: 1.6495   train/time: 28.58s   valid/time: 6.11s   train/acc: 0.7042   valid/acc: 0.4000
# Epoch 29:   train/loss: 0.5978   valid/loss: 1.6670   train/time: 27.59s   valid/time: 6.43s   train/acc: 0.7324   valid/acc: 0.4333
# Epoch 30:   train/loss: 0.5036   valid/loss: 1.0487   train/time: 27.47s   valid/time: 6.48s   train/acc: 0.7042   valid/acc: 0.4333
# Epoch 31:   train/loss: 0.3596   valid/loss: 1.0616   train/time: 28.28s   valid/time: 6.25s   train/acc: 0.7324   valid/acc: 0.4333
# Epoch 32:   train/loss: 0.6007   valid/loss: 1.0346   train/time: 27.72s   valid/time: 6.09s   train/acc: 0.7465   valid/acc: 0.4333
# Epoch 33:   train/loss: 1.3504   valid/loss: 0.9322   train/time: 28.14s   valid/time: 5.48s   train/acc: 0.7324   valid/acc: 0.4000
# Epoch 34:   train/loss: 0.4275   valid/loss: 1.5303   train/time: 28.99s   valid/time: 5.64s   train/acc: 0.7606   valid/acc: 0.4000
# Epoch 35:   train/loss: 0.6622   valid/loss: 0.8473   train/time: 29.06s   valid/time: 5.78s   train/acc: 0.6197   valid/acc: 0.4000
# Epoch 36:   train/loss: 0.5570   valid/loss: 0.8482   train/time: 29.14s   valid/time: 5.63s   train/acc: 0.6338   valid/acc: 0.4833
# Epoch 37:   train/loss: 0.6078   valid/loss: 0.8655   train/time: 28.28s   valid/time: 6.42s   train/acc: 0.6901   valid/acc: 0.4500
# Epoch 38:   train/loss: 0.4959   valid/loss: 0.8890   train/time: 27.66s   valid/time: 5.87s   train/acc: 0.6620   valid/acc: 0.4000
# Epoch 39:   train/loss: 0.4450   valid/loss: 1.0415   train/time: 27.67s   valid/time: 6.26s   train/acc: 0.6338   valid/acc: 0.4000
# Epoch 40:   train/loss: 0.4665   valid/loss: 0.9898   train/time: 28.12s   valid/time: 6.20s   train/acc: 0.6620   valid/acc: 0.4333
# Epoch 41:   train/loss: 0.5319   valid/loss: 0.8683   train/time: 28.96s   valid/time: 6.49s   train/acc: 0.8028   valid/acc: 0.4667
# Epoch 42:   train/loss: 1.4029   valid/loss: 1.3616   train/time: 28.67s   valid/time: 6.57s   train/acc: 0.6972   valid/acc: 0.4000
# Epoch 43:   train/loss: 0.6879   valid/loss: 2.0414   train/time: 28.54s   valid/time: 6.55s   train/acc: 0.6338   valid/acc: 0.4167
# Epoch 44:   train/loss: 0.8334   valid/loss: 1.8923   train/time: 30.06s   valid/time: 5.94s   train/acc: 0.6620   valid/acc: 0.4000
# Epoch 45:   train/loss: 0.9598   valid/loss: 1.5128   train/time: 26.96s   valid/time: 7.26s   train/acc: 0.6831   valid/acc: 0.4333
# Epoch 46:   train/loss: 0.5244   valid/loss: 1.2917   train/time: 27.05s   valid/time: 5.64s   train/acc: 0.5423   valid/acc: 0.3667
# Epoch 47:   train/loss: 0.6135   valid/loss: 1.3713   train/time: 27.02s   valid/time: 5.34s   train/acc: 0.6479   valid/acc: 0.4333
# Epoch 48:   train/loss: 0.4863   valid/loss: 1.2530   train/time: 30.13s   valid/time: 5.62s   train/acc: 0.6408   valid/acc: 0.4667
# Epoch 49:   train/loss: 0.6375   valid/loss: 1.2297   train/time: 27.31s   valid/time: 6.24s   train/acc: 0.6761   valid/acc: 0.4333
# Epoch 50:   train/loss: 0.5071   valid/loss: 1.1750   train/time: 28.57s   valid/time: 5.87s   train/acc: 0.7183   valid/acc: 0.4667
# Epoch 51:   train/loss: 0.7823   valid/loss: 1.7283   train/time: 27.24s   valid/time: 6.03s   train/acc: 0.7042   valid/acc: 0.4667
# Epoch 52:   train/loss: 0.5335   valid/loss: 1.1516   train/time: 27.22s   valid/time: 6.52s   train/acc: 0.7183   valid/acc: 0.4667
# Epoch 53:   train/loss: 0.4421   valid/loss: 1.1089   train/time: 27.25s   valid/time: 5.80s   train/acc: 0.7535   valid/acc: 0.4333
# Epoch 54:   train/loss: 0.4269   valid/loss: 1.0486   train/time: 30.72s   valid/time: 5.69s   train/acc: 0.7183   valid/acc: 0.4000
# Epoch 55:   train/loss: 0.4566   valid/loss: 1.0605   train/time: 28.49s   valid/time: 5.53s   train/acc: 0.7606   valid/acc: 0.4333
# Epoch 56:   train/loss: 0.3592   valid/loss: 1.0430   train/time: 28.37s   valid/time: 5.41s   train/acc: 0.6338   valid/acc: 0.4667
# Epoch 57:   train/loss: 0.3247   valid/loss: 1.0793   train/time: 27.36s   valid/time: 5.34s   train/acc: 0.8310   valid/acc: 0.5000
# Epoch 58:   train/loss: 0.2966   valid/loss: 1.1251   train/time: 27.06s   valid/time: 6.03s   train/acc: 0.7746   valid/acc: 0.4667
# Epoch 59:   train/loss: 0.3873   valid/loss: 0.9889   train/time: 26.79s   valid/time: 6.03s   train/acc: 0.6761   valid/acc: 0.5000
# Epoch 60:   train/loss: 0.5343   valid/loss: 0.9271   train/time: 28.93s   valid/time: 5.70s   train/acc: 0.7324   valid/acc: 0.4833
# Epoch 61:   train/loss: 0.3874   valid/loss: 0.9574   train/time: 27.10s   valid/time: 5.92s   train/acc: 0.8169   valid/acc: 0.4833
# Epoch 62:   train/loss: 0.5438   valid/loss: 0.9118   train/time: 26.98s   valid/time: 5.98s   train/acc: 0.7606   valid/acc: 0.5000
# Epoch 63:   train/loss: 0.6922   valid/loss: 0.9318   train/time: 28.17s   valid/time: 5.92s   train/acc: 0.8028   valid/acc: 0.5000
# Epoch 64:   train/loss: 0.4227   valid/loss: 0.9354   train/time: 27.37s   valid/time: 5.42s   train/acc: 0.7535   valid/acc: 0.5000
# Epoch 65:   train/loss: 0.3830   valid/loss: 0.9460   train/time: 28.07s   valid/time: 5.35s   train/acc: 0.8169   valid/acc: 0.4833
# Epoch 66:   train/loss: 0.3105   valid/loss: 0.9686   train/time: 27.74s   valid/time: 5.70s   train/acc: 0.7887   valid/acc: 0.4333
# Epoch 67:   train/loss: 0.5058   valid/loss: 0.9127   train/time: 27.32s   valid/time: 6.53s   train/acc: 0.7606   valid/acc: 0.4667
# Epoch 68:   train/loss: 0.4030   valid/loss: 0.9684   train/time: 28.36s   valid/time: 5.95s   train/acc: 0.7254   valid/acc: 0.5000
# Epoch 69:   train/loss: 0.3790   valid/loss: 1.0008   train/time: 28.66s   valid/time: 5.72s   train/acc: 0.7465   valid/acc: 0.5000
# Epoch 70:   train/loss: 0.4845   valid/loss: 0.9337   train/time: 28.31s   valid/time: 6.51s   train/acc: 0.8310   valid/acc: 0.4667
# Epoch 71:   train/loss: 0.3241   valid/loss: 0.9921   train/time: 27.08s   valid/time: 5.50s   train/acc: 0.8592   valid/acc: 0.5000
# Epoch 72:   train/loss: 0.3590   valid/loss: 0.9347   train/time: 27.72s   valid/time: 5.86s   train/acc: 0.7183   valid/acc: 0.5000
# Epoch 73:   train/loss: 0.4689   valid/loss: 0.8986   train/time: 27.49s   valid/time: 5.39s   train/acc: 0.8732   valid/acc: 0.5000
# Epoch 74:   train/loss: 0.5197   valid/loss: 0.8889   train/time: 27.44s   valid/time: 5.36s   train/acc: 0.8028   valid/acc: 0.5000
# Epoch 75:   train/loss: 0.4257   valid/loss: 0.8877   train/time: 27.85s   valid/time: 6.00s   train/acc: 0.7746   valid/acc: 0.5167
# Epoch 76:   train/loss: 0.4096   valid/loss: 0.8524   train/time: 26.69s   valid/time: 5.77s   train/acc: 0.8592   valid/acc: 0.5333
# Epoch 77:   train/loss: 0.5642   valid/loss: 0.9143   train/time: 27.39s   valid/time: 5.89s   train/acc: 0.8380   valid/acc: 0.5000
# Epoch 78:   train/loss: 0.4352   valid/loss: 0.9060   train/time: 29.10s   valid/time: 6.22s   train/acc: 0.8239   valid/acc: 0.5000
# Epoch 79:   train/loss: 0.2845   valid/loss: 0.8873   train/time: 27.05s   valid/time: 5.82s   train/acc: 0.8592   valid/acc: 0.5000
# Epoch 80:   train/loss: 0.3644   valid/loss: 0.8965   train/time: 26.79s   valid/time: 5.45s   train/acc: 0.8169   valid/acc: 0.5000
# Epoch 81:   train/loss: 0.4312   valid/loss: 0.8734   train/time: 26.98s   valid/time: 5.72s   train/acc: 0.7887   valid/acc: 0.5333
# Epoch 82:   train/loss: 0.4169   valid/loss: 0.8587   train/time: 26.78s   valid/time: 5.87s   train/acc: 0.8451   valid/acc: 0.5333
# Epoch 83:   train/loss: 0.3981   valid/loss: 0.8572   train/time: 26.90s   valid/time: 5.94s   train/acc: 0.8169   valid/acc: 0.5333
# Epoch 84:   train/loss: 0.5395   valid/loss: 0.8729   train/time: 27.04s   valid/time: 5.70s   train/acc: 0.8169   valid/acc: 0.5333
# Epoch 85:   train/loss: 0.3638   valid/loss: 0.8408   train/time: 27.54s   valid/time: 6.26s   train/acc: 0.7958   valid/acc: 0.5333
# Epoch 86:   train/loss: 0.3442   valid/loss: 0.8890   train/time: 26.92s   valid/time: 5.96s   train/acc: 0.8592   valid/acc: 0.5333
# Epoch 87:   train/loss: 0.4100   valid/loss: 0.9306   train/time: 27.88s   valid/time: 5.50s   train/acc: 0.8310   valid/acc: 0.5167
# Epoch 88:   train/loss: 0.3047   valid/loss: 0.9474   train/time: 27.43s   valid/time: 5.40s   train/acc: 0.7676   valid/acc: 0.5333
# Epoch 89:   train/loss: 0.3698   valid/loss: 0.8981   train/time: 26.97s   valid/time: 5.82s   train/acc: 0.8873   valid/acc: 0.5167
# Epoch 90:   train/loss: 0.4284   valid/loss: 0.9107   train/time: 27.30s   valid/time: 7.50s   train/acc: 0.8873   valid/acc: 0.5000
# Epoch 91:   train/loss: 0.5075   valid/loss: 0.9079   train/time: 26.34s   valid/time: 6.13s   train/acc: 0.8451   valid/acc: 0.4667
# Epoch 92:   train/loss: 0.4464   valid/loss: 0.9144   train/time: 26.77s   valid/time: 5.72s   train/acc: 0.7606   valid/acc: 0.5333
# Epoch 93:   train/loss: 0.3839   valid/loss: 0.8825   train/time: 26.47s   valid/time: 5.84s   train/acc: 0.8451   valid/acc: 0.5000
# Epoch 94:   train/loss: 0.3372   valid/loss: 0.9244   train/time: 26.38s   valid/time: 6.60s   train/acc: 0.8451   valid/acc: 0.5333
# Epoch 95:   train/loss: 0.4262   valid/loss: 0.8908   train/time: 26.67s   valid/time: 5.49s   train/acc: 0.8169   valid/acc: 0.5333
# Epoch 96:   train/loss: 0.4038   valid/loss: 0.8952   train/time: 26.75s   valid/time: 5.37s   train/acc: 0.8169   valid/acc: 0.5333
# Epoch 97:   train/loss: 0.3745   valid/loss: 0.9494   train/time: 26.69s   valid/time: 5.58s   train/acc: 0.8310   valid/acc: 0.4667
# Epoch 98:   train/loss: 0.5336   valid/loss: 0.8990   train/time: 28.59s   valid/time: 5.72s   train/acc: 0.8592   valid/acc: 0.5167
# Epoch 99:   train/loss: 0.3984   valid/loss: 0.8920   train/time: 26.09s   valid/time: 5.72s   train/acc: 0.8239   valid/acc: 0.5333
# Epoch 100:  train/loss: 0.3249   valid/loss: 0.8690   train/time: 26.60s   valid/time: 5.81s   train/acc: 0.8169   valid/acc: 0.5000
# Epoch 101:  train/loss: 0.4745   valid/loss: 0.8988   train/time: 28.49s   valid/time: 6.08s   train/acc: 0.8169   valid/acc: 0.5333
# Epoch 102:  train/loss: 0.2378   valid/loss: 1.0208   train/time: 27.56s   valid/time: 5.70s   train/acc: 0.8451   valid/acc: 0.5167
# Epoch 103:  train/loss: 0.5649   valid/loss: 0.8837   train/time: 27.94s   valid/time: 5.59s   train/acc: 0.8169   valid/acc: 0.5333
# Epoch 104:  train/loss: 0.3961   valid/loss: 0.9179   train/time: 30.58s   valid/time: 6.49s   train/acc: 0.8169   valid/acc: 0.5333
# Epoch 105:  train/loss: 0.5194   valid/loss: 0.9187   train/time: 32.51s   valid/time: 6.24s   train/acc: 0.8451   valid/acc: 0.5000
# Epoch 106:  train/loss: 0.4553   valid/loss: 0.8504   train/time: 30.13s   valid/time: 5.38s   train/acc: 0.8310   valid/acc: 0.5167
# Epoch 107:  train/loss: 0.3945   valid/loss: 0.8358   train/time: 27.21s   valid/time: 5.39s   train/acc: 0.7887   valid/acc: 0.5333
# Epoch 108:  train/loss: 0.4676   valid/loss: 0.8450   train/time: 27.23s   valid/time: 5.85s   train/acc: 0.8803   valid/acc: 0.5333
# Epoch 109:  train/loss: 0.5804   valid/loss: 0.8489   train/time: 26.45s   valid/time: 5.84s   train/acc: 0.8732   valid/acc: 0.5000
# Epoch 110:  train/loss: 0.5709   valid/loss: 0.9133   train/time: 26.56s   valid/time: 5.63s   train/acc: 0.8873   valid/acc: 0.5000
# Epoch 111:  train/loss: 0.4623   valid/loss: 0.9014   train/time: 25.87s   valid/time: 5.77s   train/acc: 0.8732   valid/acc: 0.5000
# Epoch 112:  train/loss: 0.2719   valid/loss: 0.8632   train/time: 27.01s   valid/time: 6.01s   train/acc: 0.8732   valid/acc: 0.5333
# Epoch 113:  train/loss: 0.5966   valid/loss: 0.8556   train/time: 28.66s   valid/time: 5.96s   train/acc: 0.8169   valid/acc: 0.5333
# Epoch 114:  train/loss: 0.3871   valid/loss: 0.8752   train/time: 26.63s   valid/time: 5.43s   train/acc: 0.8873   valid/acc: 0.5000
# Epoch 115:  train/loss: 0.5721   valid/loss: 0.8591   train/time: 27.48s   valid/time: 5.55s   train/acc: 0.8310   valid/acc: 0.5000
# Epoch 116:  train/loss: 0.3244   valid/loss: 0.8208   train/time: 27.07s   valid/time: 5.82s   train/acc: 0.8592   valid/acc: 0.5333
# Epoch 117:  train/loss: 0.2745   valid/loss: 0.8130   train/time: 26.09s   valid/time: 5.55s   train/acc: 0.9014   valid/acc: 0.5333
# Epoch 118:  train/loss: 0.6215   valid/loss: 0.8270   train/time: 26.35s   valid/time: 5.81s   train/acc: 0.8521   valid/acc: 0.5333
# Epoch 119:  train/loss: 0.5070   valid/loss: 0.8074   train/time: 26.33s   valid/time: 5.60s   train/acc: 0.8873   valid/acc: 0.5333
# Epoch 120:  train/loss: 0.2875   valid/loss: 0.7800   train/time: 26.86s   valid/time: 5.76s   train/acc: 0.8310   valid/acc: 0.5667
# Epoch 121:  train/loss: 0.2544   valid/loss: 0.8031   train/time: 26.93s   valid/time: 5.65s   train/acc: 0.9014   valid/acc: 0.5333
# Epoch 122:  train/loss: 0.2429   valid/loss: 0.7742   train/time: 28.02s   valid/time: 5.37s   train/acc: 0.8310   valid/acc: 0.5667
# Epoch 123:  train/loss: 0.5603   valid/loss: 0.8617   train/time: 26.98s   valid/time: 5.78s   train/acc: 0.8803   valid/acc: 0.5333
# Epoch 124:  train/loss: 0.2544   valid/loss: 0.8349   train/time: 26.38s   valid/time: 6.48s   train/acc: 0.8451   valid/acc: 0.5333
# Epoch 125:  train/loss: 0.2485   valid/loss: 0.8717   train/time: 28.55s   valid/time: 6.19s   train/acc: 0.8592   valid/acc: 0.5333
# Epoch 126:  train/loss: 0.3606   valid/loss: 0.7962   train/time: 28.34s   valid/time: 6.18s   train/acc: 0.8239   valid/acc: 0.5667
# Epoch 127:  train/loss: 0.3492   valid/loss: 0.8088   train/time: 27.11s   valid/time: 5.90s   train/acc: 0.8592   valid/acc: 0.5333
# Epoch 128:  train/loss: 0.1850   valid/loss: 0.7657   train/time: 27.59s   valid/time: 6.20s   train/acc: 0.8451   valid/acc: 0.6000
# Epoch 129:  train/loss: 0.4701   valid/loss: 0.8008   train/time: 28.26s   valid/time: 5.97s   train/acc: 0.8592   valid/acc: 0.6000
# Epoch 130:  train/loss: 0.3957   valid/loss: 0.8329   train/time: 28.29s   valid/time: 6.28s   train/acc: 0.8732   valid/acc: 0.5667
# Epoch 131:  train/loss: 0.3923   valid/loss: 0.8455   train/time: 28.00s   valid/time: 5.68s   train/acc: 0.8873   valid/acc: 0.5333
# Epoch 132:  train/loss: 0.3621   valid/loss: 0.8069   train/time: 33.88s   valid/time: 5.89s   train/acc: 0.7746   valid/acc: 0.5667
# Epoch 133:  train/loss: 0.3196   valid/loss: 0.8533   train/time: 27.70s   valid/time: 5.78s   train/acc: 0.8451   valid/acc: 0.5667
# Epoch 134:  train/loss: 0.3746   valid/loss: 0.8205   train/time: 28.19s   valid/time: 6.19s   train/acc: 0.8662   valid/acc: 0.5667
# Epoch 135:  train/loss: 0.2206   valid/loss: 0.7860   train/time: 27.64s   valid/time: 5.79s   train/acc: 0.8592   valid/acc: 0.5667
# Epoch 136:  train/loss: 0.3805   valid/loss: 0.8000   train/time: 27.96s   valid/time: 5.83s   train/acc: 0.9014   valid/acc: 0.5667
# Epoch 137:  train/loss: 0.1779   valid/loss: 0.8218   train/time: 28.01s   valid/time: 6.26s   train/acc: 0.8592   valid/acc: 0.5667
# Epoch 138:  train/loss: 0.4702   valid/loss: 0.8118   train/time: 28.23s   valid/time: 6.14s   train/acc: 0.8380   valid/acc: 0.5667
# Epoch 139:  train/loss: 0.2839   valid/loss: 0.8271   train/time: 29.28s   valid/time: 6.29s   train/acc: 0.8873   valid/acc: 0.5667
# Epoch 140:  train/loss: 0.3809   valid/loss: 0.8071   train/time: 27.93s   valid/time: 5.89s   train/acc: 0.9014   valid/acc: 0.5667
#
# Training completed!
# train/time: 1h5m8s   train/time_per_epoch: 27.92s   train/time_per_step: 13.96s   valid/time: 13m45s   valid/time_per_eval: 5.89s

# %%
test_acc = acc(model(test_circuits), test_labels)
print('Test accuracy:', test_acc)
# Out:
# Test accuracy: 0.7666666666666667

# %%
import matplotlib.pyplot as plt

fig, ((ax_tl, ax_tr), (ax_bl, ax_br)) = plt.subplots(2, 2, sharex=True, sharey='row', figsize=(10, 6))
ax_tl.set_title('Training set')
ax_tr.set_title('Development set')
ax_bl.set_xlabel('Iterations')
ax_br.set_xlabel('Iterations')
ax_bl.set_ylabel('Accuracy')
ax_tl.set_ylabel('Loss')
colours = iter(plt.rcParams['axes.prop_cycle'].by_key()['color'])
range_ = np.arange(1, trainer.epochs + 1)
ax_tl.plot(range_, trainer.train_epoch_costs, color=next(colours))
ax_bl.plot(range_, trainer.train_eval_results['acc'], color=next(colours))
ax_tr.plot(range_, trainer.val_costs, color=next(colours))
ax_br.plot(range_, trainer.val_eval_results['acc'], color=next(colours))

# %%
# -------------------------------
# Example: classify a new sentence
# -------------------------------
label_map = {0: "Food Class", 1: "IT Class"}
new_sentence = ["زن غذا را پخت"]   # safer than "He runs the code"

# Parse and simplify
new_diagram = remove_cups(parser.sentence2diagram(new_sentence[0]))

# Diagram -> circuit
new_circuit = ansatz(new_diagram)

# Prediction
prediction = model([new_circuit])
predicted_class = np.argmax(prediction, axis=1)[0]

print("Sentence:", new_sentence[0])
print("Prediction (raw):", prediction)
print("Predicted class:", label_map[predicted_class])
# Out:
# Sentence: زن غذا را پخت
# Prediction (raw): [[0.61445783 0.38554217]]
# Predicted class: Food Class

# %%
index=23
print(test_data[index])
print("\n")
print(model([test_circuits[index]]))
print("\n")
print(f"The Class is assigned to : {np.argmax(model([test_circuits[index]]))}")
print(f"The True Class Label is : {int(np.argmax(test_labels[index]))}")   # for food label is 1 so --> [1 0]

print("Label=0 is for Food class and Label=1 is for IT class")
# Out:
# زن ماهر شام را درست کرد.
#
#
# [[0.30536913 0.69463087]]
#
#
# The Class is assigned to : 1
# The True Class Label is : 0
# Label=0 is for Food class and Label=1 is for IT class

# %%
labels, sentences = read_data("datasets/mc_test_data.txt")
for i in range(5):
    print(sentences[i], labels[i])
# Out:
# زن شام خوشمزه را آماده کرد. [1, 0]
# زن ماهر نرم افزار را اماده کرد. [0, 1]
# مرد ماهر شام را آماده کرد. [1, 0]
# زن ماهر سس را پخت. [1, 0]
# زن برنامه مناسب را اجرا کرد [0, 1]
