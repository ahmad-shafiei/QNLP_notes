# %% [markdown]
# ## New Simple QNLP Project

# %% [markdown]
# ## Main Project

# %%
from preprocess import normalize_text, tokenize_text, \
                        merge_compound_verbs,label_roles
txt1 = ' ?!!احمد غذا خوشمزه را خورد '
txt2 = 'رضا برنامه را ران گرفت'
txt3 = "مرد برنامه مناسب را اشکالزدایی کرد"
txt1 = normalize_text(txt1)
txt2 = normalize_text(txt2)

tokens1= (tokenize_text(txt1))
tokens2= (tokenize_text(txt2))

print(tokenize_text(txt1))
print(merge_compound_verbs(tokens2))

print(label_roles(tokens1))
# Out:
# ['احمد', 'غذا', 'خوشمزه', 'را', 'خورد']
# ['رضا', 'برنامه', 'را', 'ران_گرفت']
# [('احمد', 'subj'), ('غذا', 'obj'), ('خوشمزه', 'adj'), ('را', 'other'), ('خورد', 'verb')]

# %%
from persian_cat_parser import PersianCatParser
sent1 = "مرد غذا  را پخت"
# sent1 = "مرد ماهر نرم افزار مناسب را اجرا کرد"
sent1 = "مرد برنامه را اشکالزدایی کرد"

parser = PersianCatParser()
sent1 = "شخص نرم افزار مناسب را اشکالزدایی کرد"
diagram = parser.sentence2diagram(sent1)
diagram.draw()

# %%
from persian_cat_parser import PersianCatParser
from preprocess import read_data

train_labels, train_data = read_data("datasets/mc_train_data.txt")   # label [t 1-t]
dev_labels, dev_data     = read_data("datasets/mc_dev_data.txt")
test_labels, test_data   = read_data("datasets/mc_test_data.txt")

parser = PersianCatParser(verbose=True)

raw_train_diagrams = parser.sentences2diagrams(train_data)
raw_dev_diagrams   = parser.sentences2diagrams(dev_data)
raw_test_diagrams  = parser.sentences2diagrams(test_data)

# %%
# انتخاب یک جمله و نمایش ان
idx = 35 
sent = train_data[idx]
# sent = "مرد غذای خوشمزه را پخت"

d = parser.sentence2diagram(sent)
print("Sentence:", sent)
# print("Diagram:", d)
d.draw()
# Out:
# Sentence: زن برنامه را اجرا کرد.

# %% [markdown]
# ### Create Diagram

# %%
# print(train_data[14])
# raw_train_diagrams[14].draw()
import matplotlib.pyplot as plt
from matplotlib import rcParams

# معرفی فونت فارسی
rcParams['font.family'] = 'Tahoma'   # یا مثلاً 'Vazirmatn' اگر نصب باشه
raw_train_diagrams[29].draw(size='18')
plt.show()

# %%
from persian_cat_parser import PersianCatParser
from preprocess import read_data

train_labels, train_data = read_data("datasets/mc_train_data.txt")   # label [t 1-t]
parser = PersianCatParser(verbose=True)
raw_train_diagrams = parser.sentences2diagrams(train_data)
idx = 34 
sent = train_data[idx]
d = parser.sentence2diagram(sent)
print("Sentence:", sent)
d.draw()
# Out:
# Sentence: زن شام را پخت.

# %% [markdown]
# ### Remove the Cups

# %%
from lambeq import RemoveCupsRewriter
remove_cups = RemoveCupsRewriter()

train_diagrams = [remove_cups(diagram) for diagram in raw_train_diagrams]
dev_diagrams   = [remove_cups(diagram) for diagram in raw_dev_diagrams  ]
test_diagrams  = [remove_cups(diagram) for diagram in raw_test_diagrams ]

train_diagrams[14].draw()

# %% [markdown]
# ### Create Circuits

# %%
from lambeq import AtomicType, IQPAnsatz
from lambeq.backend.grammar import Cup, Word, Diagram, Id, Swap, Ty

ansatz = IQPAnsatz({AtomicType.NOUN: 1, AtomicType.SENTENCE: 1, Ty('o'):1}, n_layers=1, n_single_qubit_params=3)

train_circuits = [ansatz(diagram) for diagram in train_diagrams]
dev_circuits   = [ansatz(diagram) for diagram in dev_diagrams  ]
test_circuits  = [ansatz(diagram) for diagram in test_diagrams ]

train_circuits[0].draw(figsize=(9, 9))

# %% [markdown]
# ## the main persian project for ML learning

# %%
from persian_cat_parser import PersianCatParser
from preprocess import read_data

train_labels, train_data = read_data("datasets/mc_train_data.txt")   # label [t 1-t]
dev_labels, dev_data     = read_data("datasets/mc_dev_data.txt")
test_labels, test_data   = read_data("datasets/mc_test_data.txt")

parser = PersianCatParser(verbose=True)

raw_train_diagrams = parser.sentences2diagrams(train_data)
raw_dev_diagrams   = parser.sentences2diagrams(dev_data)
raw_test_diagrams  = parser.sentences2diagrams(test_data)

# %%
from lambeq import RemoveCupsRewriter 

remove_cups = RemoveCupsRewriter()
train_diagrams = [remove_cups(diagram) for diagram in raw_train_diagrams]
dev_diagrams   = [remove_cups(diagram) for diagram in raw_dev_diagrams  ]
test_diagrams  = [remove_cups(diagram) for diagram in raw_test_diagrams ]

# %%
from lambeq import IQPAnsatz
from lambeq import AtomicType
ansatz = IQPAnsatz({AtomicType.NOUN: 1, AtomicType.SENTENCE: 1, Ty('o'):1}, n_layers=1, n_single_qubit_params=3)
train_circuits = [ansatz(diagram) for diagram in train_diagrams]
dev_circuits   = [ansatz(diagram) for diagram in dev_diagrams  ]
test_circuits  = [ansatz(diagram) for diagram in test_diagrams ]

# %%
# -------------------------------
# Backend and model
# -------------------------------
from lambeq import TketModel
from pytket.extensions.qiskit import AerBackend

backend = AerBackend()
backend_config = {
    'backend': backend,
    'compilation': backend.default_compilation_pass(2),
    'shots': 8192
}
all_circuits = train_circuits + dev_circuits + test_circuits
model = TketModel.from_diagrams(all_circuits, backend_config=backend_config)

# %%
# -------------------------------
# Training setup
# -------------------------------
from lambeq import BinaryCrossEntropyLoss
from lambeq import QuantumTrainer, SPSAOptimizer
import numpy as np

bce = BinaryCrossEntropyLoss()
acc = lambda y_hat, y: np.sum(np.round(y_hat) == y) / len(y) / 2

BATCH_SIZE = 30
EPOCHS = 140

trainer = QuantumTrainer(
    model,
    loss_function=bce,
    epochs=EPOCHS,
    optimizer=SPSAOptimizer,
    optim_hyperparams={'a': 0.05, 'c': 0.06, 'A': 0.01 * EPOCHS},
    evaluate_functions={'acc': acc},
    evaluate_on_train=True,
    verbose='text',
    seed=2,
)

# %%
# -------------------------------
# Prepare datasets
# -------------------------------
from lambeq import Dataset
train_dataset = Dataset(train_circuits, train_labels, batch_size=BATCH_SIZE)
val_dataset   = Dataset(dev_circuits, dev_labels, shuffle=False)

# Train
trainer.fit(train_dataset, val_dataset, log_interval=1)
# Out:
# Epoch 1:    train/loss: 1.9313   valid/loss: 0.7920   train/time: 28.24s   valid/time: 7.86s   train/acc: 0.4718   valid/acc: 0.5333
# Epoch 2:    train/loss: 0.8232   valid/loss: 0.8414   train/time: 27.69s   valid/time: 5.53s   train/acc: 0.5211   valid/acc: 0.5500
# Epoch 3:    train/loss: 0.7751   valid/loss: 1.4953   train/time: 27.60s   valid/time: 5.71s   train/acc: 0.6056   valid/acc: 0.5000
# Epoch 4:    train/loss: 1.7915   valid/loss: 0.9706   train/time: 28.00s   valid/time: 5.49s   train/acc: 0.5070   valid/acc: 0.4667
# Epoch 5:    train/loss: 0.8167   valid/loss: 0.6993   train/time: 27.69s   valid/time: 5.65s   train/acc: 0.5000   valid/acc: 0.6333
# Epoch 6:    train/loss: 1.6721   valid/loss: 0.8375   train/time: 27.61s   valid/time: 5.95s   train/acc: 0.5282   valid/acc: 0.5667
# Epoch 7:    train/loss: 1.9616   valid/loss: 1.1423   train/time: 28.11s   valid/time: 5.58s   train/acc: 0.4859   valid/acc: 0.4000
# Epoch 8:    train/loss: 2.1859   valid/loss: 1.0612   train/time: 26.93s   valid/time: 6.17s   train/acc: 0.4859   valid/acc: 0.4333
# Epoch 9:    train/loss: 2.0321   valid/loss: 1.7497   train/time: 27.37s   valid/time: 6.07s   train/acc: 0.5493   valid/acc: 0.3667
# Epoch 10:   train/loss: 0.7265   valid/loss: 1.1223   train/time: 26.68s   valid/time: 5.94s   train/acc: 0.4789   valid/acc: 0.3667
# Epoch 11:   train/loss: 0.7736   valid/loss: 1.6158   train/time: 27.04s   valid/time: 5.50s   train/acc: 0.5000   valid/acc: 0.4000
# Epoch 12:   train/loss: 1.0927   valid/loss: 1.0758   train/time: 27.82s   valid/time: 5.77s   train/acc: 0.4718   valid/acc: 0.3833
# Epoch 13:   train/loss: 0.9078   valid/loss: 0.9923   train/time: 29.59s   valid/time: 5.62s   train/acc: 0.5423   valid/acc: 0.4333
# Epoch 14:   train/loss: 0.6722   valid/loss: 1.5972   train/time: 27.21s   valid/time: 5.45s   train/acc: 0.5915   valid/acc: 0.3500
# Epoch 15:   train/loss: 0.7050   valid/loss: 0.9137   train/time: 27.43s   valid/time: 5.55s   train/acc: 0.5423   valid/acc: 0.3500
# Epoch 16:   train/loss: 0.7768   valid/loss: 0.8963   train/time: 27.28s   valid/time: 5.69s   train/acc: 0.5211   valid/acc: 0.4667
# Epoch 17:   train/loss: 0.8218   valid/loss: 0.9425   train/time: 26.77s   valid/time: 5.88s   train/acc: 0.5070   valid/acc: 0.4000
# Epoch 18:   train/loss: 0.9690   valid/loss: 0.9382   train/time: 26.34s   valid/time: 6.33s   train/acc: 0.5070   valid/acc: 0.4833
# Epoch 19:   train/loss: 0.9724   valid/loss: 1.5661   train/time: 26.72s   valid/time: 5.57s   train/acc: 0.5141   valid/acc: 0.5333
# Epoch 20:   train/loss: 0.7624   valid/loss: 1.5573   train/time: 26.93s   valid/time: 5.75s   train/acc: 0.6268   valid/acc: 0.5333
# Epoch 21:   train/loss: 0.5100   valid/loss: 2.0606   train/time: 27.09s   valid/time: 5.47s   train/acc: 0.6197   valid/acc: 0.5000
# Epoch 22:   train/loss: 0.8546   valid/loss: 0.8108   train/time: 27.28s   valid/time: 5.38s   train/acc: 0.6408   valid/acc: 0.5000
# Epoch 23:   train/loss: 0.9379   valid/loss: 0.8295   train/time: 28.58s   valid/time: 5.53s   train/acc: 0.5775   valid/acc: 0.5333
# Epoch 24:   train/loss: 0.8122   valid/loss: 0.7666   train/time: 27.53s   valid/time: 6.37s   train/acc: 0.5986   valid/acc: 0.5000
# Epoch 25:   train/loss: 0.9065   valid/loss: 0.7268   train/time: 26.51s   valid/time: 6.23s   train/acc: 0.5563   valid/acc: 0.6333
# Epoch 26:   train/loss: 0.7344   valid/loss: 0.7607   train/time: 27.77s   valid/time: 6.07s   train/acc: 0.6056   valid/acc: 0.6667
# Epoch 27:   train/loss: 0.6822   valid/loss: 0.7781   train/time: 29.44s   valid/time: 5.59s   train/acc: 0.6197   valid/acc: 0.5667
# Epoch 28:   train/loss: 1.4150   valid/loss: 0.7627   train/time: 27.62s   valid/time: 5.80s   train/acc: 0.6549   valid/acc: 0.6000
# Epoch 29:   train/loss: 0.9563   valid/loss: 0.8085   train/time: 27.85s   valid/time: 5.77s   train/acc: 0.6761   valid/acc: 0.5333
# Epoch 30:   train/loss: 0.7307   valid/loss: 0.7447   train/time: 27.47s   valid/time: 5.80s   train/acc: 0.5915   valid/acc: 0.5167
# Epoch 31:   train/loss: 1.4422   valid/loss: 0.9020   train/time: 28.64s   valid/time: 5.74s   train/acc: 0.6408   valid/acc: 0.5333
# Epoch 32:   train/loss: 0.8891   valid/loss: 0.8893   train/time: 28.05s   valid/time: 5.61s   train/acc: 0.5563   valid/acc: 0.5500
# Epoch 33:   train/loss: 0.5891   valid/loss: 2.0438   train/time: 27.53s   valid/time: 5.80s   train/acc: 0.6479   valid/acc: 0.5500
# Epoch 34:   train/loss: 0.7994   valid/loss: 0.8796   train/time: 28.63s   valid/time: 5.58s   train/acc: 0.5563   valid/acc: 0.5500
# Epoch 35:   train/loss: 1.1134   valid/loss: 0.8991   train/time: 28.10s   valid/time: 6.28s   train/acc: 0.5070   valid/acc: 0.5667
# Epoch 36:   train/loss: 1.7878   valid/loss: 0.7917   train/time: 27.27s   valid/time: 5.97s   train/acc: 0.5282   valid/acc: 0.5833
# Epoch 37:   train/loss: 0.5246   valid/loss: 0.7461   train/time: 27.12s   valid/time: 5.76s   train/acc: 0.6197   valid/acc: 0.6667
# Epoch 38:   train/loss: 0.7734   valid/loss: 0.8231   train/time: 28.59s   valid/time: 5.93s   train/acc: 0.7183   valid/acc: 0.5667
# Epoch 39:   train/loss: 0.6263   valid/loss: 0.7659   train/time: 28.76s   valid/time: 6.00s   train/acc: 0.5915   valid/acc: 0.6000
# Epoch 40:   train/loss: 0.6706   valid/loss: 0.7674   train/time: 28.98s   valid/time: 5.84s   train/acc: 0.6197   valid/acc: 0.5333
# Epoch 41:   train/loss: 1.3968   valid/loss: 1.4307   train/time: 29.50s   valid/time: 5.95s   train/acc: 0.6408   valid/acc: 0.5000
# Epoch 42:   train/loss: 1.6975   valid/loss: 1.5493   train/time: 29.32s   valid/time: 6.22s   train/acc: 0.6056   valid/acc: 0.5500
# Epoch 43:   train/loss: 1.7833   valid/loss: 1.5468   train/time: 28.65s   valid/time: 6.17s   train/acc: 0.4930   valid/acc: 0.4667
# Epoch 44:   train/loss: 0.5810   valid/loss: 1.4211   train/time: 28.36s   valid/time: 5.98s   train/acc: 0.5634   valid/acc: 0.5833
# Epoch 45:   train/loss: 0.6832   valid/loss: 1.5526   train/time: 28.52s   valid/time: 6.06s   train/acc: 0.6197   valid/acc: 0.4500
# Epoch 46:   train/loss: 0.9481   valid/loss: 0.9139   train/time: 29.15s   valid/time: 5.88s   train/acc: 0.4507   valid/acc: 0.5167
# Epoch 47:   train/loss: 0.6696   valid/loss: 1.6188   train/time: 29.26s   valid/time: 6.74s   train/acc: 0.5000   valid/acc: 0.4167
# Epoch 48:   train/loss: 0.6144   valid/loss: 0.9223   train/time: 28.53s   valid/time: 5.86s   train/acc: 0.5070   valid/acc: 0.5000
# Epoch 49:   train/loss: 0.9054   valid/loss: 0.9601   train/time: 29.34s   valid/time: 6.04s   train/acc: 0.5563   valid/acc: 0.4667
# Epoch 50:   train/loss: 0.9075   valid/loss: 1.0348   train/time: 28.29s   valid/time: 6.81s   train/acc: 0.6197   valid/acc: 0.3667
# Epoch 51:   train/loss: 0.4991   valid/loss: 1.5626   train/time: 28.13s   valid/time: 6.24s   train/acc: 0.5634   valid/acc: 0.5000
# Epoch 52:   train/loss: 1.0542   valid/loss: 0.9852   train/time: 28.64s   valid/time: 6.75s   train/acc: 0.6338   valid/acc: 0.4167
# Epoch 53:   train/loss: 0.8806   valid/loss: 1.6181   train/time: 28.74s   valid/time: 6.06s   train/acc: 0.6197   valid/acc: 0.4000
# Epoch 54:   train/loss: 0.6742   valid/loss: 1.6171   train/time: 28.68s   valid/time: 5.86s   train/acc: 0.5845   valid/acc: 0.4000
# Epoch 55:   train/loss: 0.6678   valid/loss: 1.6300   train/time: 29.25s   valid/time: 5.97s   train/acc: 0.5915   valid/acc: 0.3667
# Epoch 56:   train/loss: 0.7325   valid/loss: 0.8999   train/time: 28.98s   valid/time: 5.89s   train/acc: 0.5493   valid/acc: 0.4167
# Epoch 57:   train/loss: 0.7284   valid/loss: 1.6365   train/time: 30.18s   valid/time: 5.93s   train/acc: 0.6408   valid/acc: 0.4667
# Epoch 58:   train/loss: 0.7639   valid/loss: 1.6642   train/time: 29.67s   valid/time: 5.97s   train/acc: 0.5352   valid/acc: 0.3833
# Epoch 59:   train/loss: 0.6062   valid/loss: 1.7040   train/time: 30.84s   valid/time: 7.41s   train/acc: 0.5493   valid/acc: 0.4167
# Epoch 60:   train/loss: 0.5424   valid/loss: 1.6703   train/time: 31.63s   valid/time: 7.40s   train/acc: 0.5915   valid/acc: 0.4833
# Epoch 61:   train/loss: 0.8366   valid/loss: 0.9697   train/time: 31.80s   valid/time: 7.51s   train/acc: 0.5563   valid/acc: 0.4167
# Epoch 62:   train/loss: 1.7639   valid/loss: 1.7673   train/time: 29.05s   valid/time: 5.84s   train/acc: 0.6761   valid/acc: 0.4667
# Epoch 63:   train/loss: 0.6125   valid/loss: 2.3329   train/time: 33.26s   valid/time: 6.27s   train/acc: 0.4930   valid/acc: 0.3833
# Epoch 64:   train/loss: 1.0436   valid/loss: 1.0539   train/time: 28.51s   valid/time: 5.62s   train/acc: 0.5141   valid/acc: 0.4333
# Epoch 65:   train/loss: 0.9444   valid/loss: 1.6254   train/time: 27.67s   valid/time: 5.62s   train/acc: 0.5070   valid/acc: 0.4000
# Epoch 66:   train/loss: 0.5828   valid/loss: 1.6188   train/time: 27.56s   valid/time: 5.81s   train/acc: 0.5493   valid/acc: 0.3667
# Epoch 67:   train/loss: 0.6162   valid/loss: 0.9493   train/time: 26.80s   valid/time: 5.79s   train/acc: 0.5141   valid/acc: 0.4000
# Epoch 68:   train/loss: 0.7661   valid/loss: 1.5871   train/time: 27.09s   valid/time: 6.52s   train/acc: 0.4930   valid/acc: 0.4167
# Epoch 69:   train/loss: 0.7625   valid/loss: 0.8672   train/time: 29.31s   valid/time: 6.81s   train/acc: 0.5493   valid/acc: 0.4833
# Epoch 70:   train/loss: 0.8794   valid/loss: 1.5240   train/time: 27.70s   valid/time: 5.58s   train/acc: 0.4789   valid/acc: 0.4167
# Epoch 71:   train/loss: 0.7960   valid/loss: 0.9710   train/time: 28.56s   valid/time: 5.65s   train/acc: 0.5423   valid/acc: 0.3833
# Epoch 72:   train/loss: 1.5979   valid/loss: 2.2675   train/time: 28.01s   valid/time: 5.67s   train/acc: 0.3451   valid/acc: 0.4333
# Epoch 73:   train/loss: 0.5955   valid/loss: 2.0821   train/time: 28.79s   valid/time: 6.52s   train/acc: 0.4648   valid/acc: 0.4667
# Epoch 74:   train/loss: 0.6716   valid/loss: 2.1106   train/time: 27.64s   valid/time: 5.81s   train/acc: 0.5493   valid/acc: 0.4667
# Epoch 75:   train/loss: 0.9492   valid/loss: 1.7459   train/time: 28.11s   valid/time: 6.10s   train/acc: 0.5634   valid/acc: 0.4000
# Epoch 76:   train/loss: 0.5845   valid/loss: 1.5154   train/time: 27.76s   valid/time: 5.99s   train/acc: 0.6479   valid/acc: 0.4667
# Epoch 77:   train/loss: 0.9583   valid/loss: 1.0501   train/time: 26.88s   valid/time: 6.23s   train/acc: 0.5704   valid/acc: 0.4333
# Epoch 78:   train/loss: 0.7404   valid/loss: 1.8495   train/time: 31.81s   valid/time: 6.75s   train/acc: 0.5775   valid/acc: 0.5000
# Epoch 79:   train/loss: 0.9765   valid/loss: 1.7057   train/time: 27.17s   valid/time: 6.07s   train/acc: 0.6620   valid/acc: 0.4833
# Epoch 80:   train/loss: 0.3981   valid/loss: 1.1214   train/time: 27.43s   valid/time: 5.44s   train/acc: 0.5352   valid/acc: 0.4667
# Epoch 81:   train/loss: 0.4654   valid/loss: 1.0638   train/time: 27.64s   valid/time: 5.52s   train/acc: 0.6338   valid/acc: 0.5667
# Epoch 82:   train/loss: 0.6547   valid/loss: 0.9692   train/time: 28.38s   valid/time: 5.99s   train/acc: 0.6338   valid/acc: 0.4833
# Epoch 83:   train/loss: 0.7113   valid/loss: 1.6423   train/time: 27.60s   valid/time: 5.72s   train/acc: 0.6127   valid/acc: 0.4667
# Epoch 84:   train/loss: 0.6964   valid/loss: 1.0381   train/time: 27.93s   valid/time: 5.76s   train/acc: 0.5915   valid/acc: 0.4000
# Epoch 85:   train/loss: 0.7887   valid/loss: 0.9565   train/time: 27.91s   valid/time: 5.86s   train/acc: 0.6056   valid/acc: 0.5000
# Epoch 86:   train/loss: 1.0298   valid/loss: 0.9390   train/time: 27.47s   valid/time: 5.98s   train/acc: 0.6620   valid/acc: 0.5333
# Epoch 87:   train/loss: 0.9758   valid/loss: 0.9133   train/time: 26.77s   valid/time: 6.00s   train/acc: 0.6620   valid/acc: 0.4667
# Epoch 88:   train/loss: 0.7465   valid/loss: 0.9521   train/time: 27.43s   valid/time: 5.51s   train/acc: 0.6901   valid/acc: 0.4667
# Epoch 89:   train/loss: 0.6837   valid/loss: 1.6125   train/time: 30.09s   valid/time: 5.71s   train/acc: 0.5986   valid/acc: 0.5333
# Epoch 90:   train/loss: 0.7737   valid/loss: 1.0327   train/time: 27.78s   valid/time: 5.77s   train/acc: 0.6268   valid/acc: 0.5167
# Epoch 91:   train/loss: 0.6384   valid/loss: 1.0226   train/time: 28.35s   valid/time: 5.63s   train/acc: 0.6620   valid/acc: 0.5333
# Epoch 92:   train/loss: 0.7149   valid/loss: 1.6789   train/time: 32.21s   valid/time: 5.65s   train/acc: 0.6549   valid/acc: 0.5000
# Epoch 93:   train/loss: 0.4166   valid/loss: 1.6828   train/time: 29.45s   valid/time: 6.21s   train/acc: 0.5845   valid/acc: 0.5000
# Epoch 94:   train/loss: 0.7330   valid/loss: 1.0160   train/time: 29.19s   valid/time: 5.75s   train/acc: 0.5915   valid/acc: 0.5333
# Epoch 95:   train/loss: 0.9656   valid/loss: 1.6352   train/time: 28.27s   valid/time: 5.70s   train/acc: 0.5211   valid/acc: 0.5000
# Epoch 96:   train/loss: 0.7228   valid/loss: 1.6519   train/time: 28.07s   valid/time: 5.89s   train/acc: 0.7042   valid/acc: 0.4667
# Epoch 97:   train/loss: 0.8163   valid/loss: 1.1863   train/time: 27.68s   valid/time: 5.86s   train/acc: 0.5775   valid/acc: 0.4667
# Epoch 98:   train/loss: 0.6144   valid/loss: 1.1364   train/time: 27.05s   valid/time: 6.22s   train/acc: 0.6056   valid/acc: 0.5000
# Epoch 99:   train/loss: 0.5211   valid/loss: 1.0663   train/time: 27.78s   valid/time: 5.93s   train/acc: 0.6338   valid/acc: 0.5167
# Epoch 100:  train/loss: 0.8027   valid/loss: 1.1292   train/time: 28.36s   valid/time: 5.66s   train/acc: 0.6268   valid/acc: 0.4667
# Epoch 101:  train/loss: 0.6994   valid/loss: 1.6626   train/time: 28.16s   valid/time: 5.64s   train/acc: 0.6479   valid/acc: 0.4667
# Epoch 102:  train/loss: 0.4803   valid/loss: 1.1231   train/time: 27.75s   valid/time: 7.26s   train/acc: 0.6197   valid/acc: 0.4667
# Epoch 103:  train/loss: 0.5325   valid/loss: 1.1500   train/time: 31.72s   valid/time: 5.83s   train/acc: 0.7113   valid/acc: 0.5000
# Epoch 104:  train/loss: 0.7288   valid/loss: 1.2161   train/time: 26.98s   valid/time: 5.56s   train/acc: 0.6268   valid/acc: 0.4333
# Epoch 105:  train/loss: 0.5996   valid/loss: 1.1688   train/time: 26.93s   valid/time: 5.48s   train/acc: 0.6408   valid/acc: 0.4667
# Epoch 106:  train/loss: 0.7916   valid/loss: 1.7845   train/time: 27.05s   valid/time: 5.52s   train/acc: 0.6268   valid/acc: 0.5000
# Epoch 107:  train/loss: 0.5457   valid/loss: 1.8737   train/time: 27.62s   valid/time: 5.59s   train/acc: 0.6408   valid/acc: 0.4333
# Epoch 108:  train/loss: 0.5900   valid/loss: 1.1768   train/time: 27.45s   valid/time: 5.96s   train/acc: 0.6338   valid/acc: 0.5000
# Epoch 109:  train/loss: 0.6143   valid/loss: 1.8753   train/time: 30.83s   valid/time: 5.54s   train/acc: 0.6197   valid/acc: 0.5000
# Epoch 110:  train/loss: 0.8013   valid/loss: 1.1439   train/time: 26.45s   valid/time: 5.49s   train/acc: 0.6338   valid/acc: 0.4333
# Epoch 111:  train/loss: 0.6768   valid/loss: 1.2395   train/time: 25.94s   valid/time: 5.72s   train/acc: 0.6620   valid/acc: 0.4333
# Epoch 112:  train/loss: 0.6933   valid/loss: 1.8595   train/time: 27.35s   valid/time: 5.54s   train/acc: 0.5986   valid/acc: 0.4167
# Epoch 113:  train/loss: 0.6459   valid/loss: 1.7594   train/time: 26.33s   valid/time: 5.89s   train/acc: 0.6479   valid/acc: 0.4333
# Epoch 114:  train/loss: 0.4999   valid/loss: 1.7678   train/time: 26.86s   valid/time: 5.57s   train/acc: 0.7183   valid/acc: 0.5000
# Epoch 115:  train/loss: 0.7368   valid/loss: 1.7463   train/time: 27.97s   valid/time: 5.58s   train/acc: 0.6690   valid/acc: 0.4667
# Epoch 116:  train/loss: 0.6108   valid/loss: 1.2175   train/time: 27.46s   valid/time: 5.80s   train/acc: 0.6901   valid/acc: 0.4333
# Epoch 117:  train/loss: 0.6978   valid/loss: 1.8363   train/time: 28.09s   valid/time: 5.68s   train/acc: 0.6338   valid/acc: 0.4333
# Epoch 118:  train/loss: 0.5898   valid/loss: 1.8810   train/time: 28.17s   valid/time: 5.49s   train/acc: 0.6690   valid/acc: 0.5333
# Epoch 119:  train/loss: 0.7263   valid/loss: 1.2558   train/time: 27.08s   valid/time: 5.71s   train/acc: 0.6620   valid/acc: 0.4333
# Epoch 120:  train/loss: 0.4450   valid/loss: 1.7707   train/time: 26.09s   valid/time: 5.56s   train/acc: 0.6761   valid/acc: 0.4667
# Epoch 121:  train/loss: 0.6062   valid/loss: 1.7739   train/time: 26.54s   valid/time: 5.63s   train/acc: 0.7042   valid/acc: 0.4667
# Epoch 122:  train/loss: 0.5004   valid/loss: 1.1760   train/time: 26.67s   valid/time: 5.54s   train/acc: 0.7183   valid/acc: 0.5000
# Epoch 123:  train/loss: 1.5039   valid/loss: 1.0776   train/time: 26.26s   valid/time: 5.49s   train/acc: 0.6479   valid/acc: 0.4667
# Epoch 124:  train/loss: 0.5284   valid/loss: 1.2104   train/time: 26.44s   valid/time: 5.47s   train/acc: 0.7465   valid/acc: 0.4667
# Epoch 125:  train/loss: 0.4633   valid/loss: 1.7495   train/time: 26.06s   valid/time: 5.49s   train/acc: 0.7042   valid/acc: 0.5333
# Epoch 126:  train/loss: 1.0023   valid/loss: 1.1453   train/time: 26.30s   valid/time: 6.28s   train/acc: 0.6479   valid/acc: 0.5167
# Epoch 127:  train/loss: 0.5406   valid/loss: 1.2360   train/time: 26.70s   valid/time: 5.45s   train/acc: 0.7042   valid/acc: 0.4667
# Epoch 128:  train/loss: 0.5758   valid/loss: 1.2160   train/time: 26.08s   valid/time: 6.03s   train/acc: 0.6620   valid/acc: 0.4667
# Epoch 129:  train/loss: 0.5086   valid/loss: 1.2040   train/time: 26.30s   valid/time: 5.58s   train/acc: 0.7042   valid/acc: 0.5000
# Epoch 130:  train/loss: 0.4690   valid/loss: 1.1582   train/time: 27.18s   valid/time: 5.55s   train/acc: 0.5775   valid/acc: 0.4667
# Epoch 131:  train/loss: 0.6276   valid/loss: 1.1141   train/time: 26.46s   valid/time: 6.00s   train/acc: 0.6620   valid/acc: 0.5333
# Epoch 132:  train/loss: 0.8235   valid/loss: 1.8405   train/time: 26.21s   valid/time: 5.82s   train/acc: 0.6549   valid/acc: 0.4667
# Epoch 133:  train/loss: 0.8163   valid/loss: 1.8428   train/time: 26.47s   valid/time: 5.50s   train/acc: 0.7042   valid/acc: 0.4333
# Epoch 134:  train/loss: 0.6186   valid/loss: 1.0868   train/time: 26.30s   valid/time: 5.62s   train/acc: 0.6197   valid/acc: 0.5333
# Epoch 135:  train/loss: 0.6477   valid/loss: 1.6870   train/time: 26.84s   valid/time: 5.50s   train/acc: 0.6338   valid/acc: 0.4833
# Epoch 136:  train/loss: 0.5521   valid/loss: 2.2738   train/time: 26.59s   valid/time: 5.48s   train/acc: 0.6761   valid/acc: 0.5000
# Epoch 137:  train/loss: 0.6596   valid/loss: 1.1613   train/time: 26.45s   valid/time: 5.47s   train/acc: 0.7113   valid/acc: 0.4667
# Epoch 138:  train/loss: 0.7958   valid/loss: 1.7313   train/time: 26.08s   valid/time: 5.46s   train/acc: 0.6620   valid/acc: 0.4167
# Epoch 139:  train/loss: 0.7464   valid/loss: 1.6999   train/time: 26.51s   valid/time: 5.57s   train/acc: 0.6620   valid/acc: 0.5000
# Epoch 140:  train/loss: 0.6177   valid/loss: 1.7266   train/time: 25.92s   valid/time: 5.93s   train/acc: 0.7113   valid/acc: 0.4833
#
# Training completed!
# train/time: 1h5m8s   train/time_per_epoch: 27.92s   train/time_per_step: 9.31s   valid/time: 13m44s   valid/time_per_eval: 5.89s

# %%
test_acc = acc(model(test_circuits), test_labels)
print('Test accuracy:', test_acc)
# Out:
# Test accuracy: 0.36666666666666664

# %%
import matplotlib.pyplot as plt

fig, ((ax_tl, ax_tr), (ax_bl, ax_br)) = plt.subplots(2, 2, sharex=True, sharey='row', figsize=(10, 6))
ax_tl.set_title('Training set')
ax_tr.set_title('Development set')
ax_bl.set_xlabel('Iterations')
ax_br.set_xlabel('Iterations')
ax_bl.set_ylabel('Accuracy')
ax_tl.set_ylabel('Loss')
colours = iter(plt.rcParams['axes.prop_cycle'].by_key()['color'])
range_ = np.arange(1, trainer.epochs + 1)
ax_tl.plot(range_, trainer.train_epoch_costs, color=next(colours))
ax_bl.plot(range_, trainer.train_eval_results['acc'], color=next(colours))
ax_tr.plot(range_, trainer.val_costs, color=next(colours))
ax_br.plot(range_, trainer.val_eval_results['acc'], color=next(colours))

# %%
# -------------------------------
# Example: classify a new sentence
# -------------------------------
label_map = {0: "Food Class", 1: "IT Class"}
new_sentence = ["زن غذا را خورد"]   # safer than "He runs the code"

# Parse and simplify
new_diagram = remove_cups(parser.sentence2diagram(new_sentence[0]))

# Diagram -> circuit
new_circuit = ansatz(new_diagram)

# Prediction
prediction = model([new_circuit])
predicted_class = np.argmax(prediction, axis=1)[0]

print("Sentence:", new_sentence[0])
print("Prediction (raw):", prediction)
print("Predicted class:", label_map[predicted_class])
# Out:
# Sentence: زن غذا را خورد
# Prediction (raw): [[0.31851852 0.68148148]]
# Predicted class: IT Class

# %%
index=23
print(test_data[index])
print("\n")
print(model([test_circuits[index]]))
print("\n")
print(f"The Class is assigned to : {np.argmax(model([test_circuits[index]]))}")
print(f"The True Class Label is : {int(np.argmax(test_labels[index]))}")   # for food label is 1 so --> [1 0]

print("Label=0 is for Food class and Label=1 is for IT class")
# Out:
# حسین مرورگر را اجرا کرد
#
#
# [[0.74698795 0.25301205]]
#
#
# The Class is assigned to : 0
# The True Class Label is : 1
# Label=0 is for Food class and Label=1 is for IT class

# %%
labels, sentences = read_data("datasets/mc_test_data.txt")
for i in range(5):
    print(sentences[i], labels[i])
# Out:
# سارا لپ‌تاپ را روشن کرد [0, 1]
# نرگس برنج را دم کرد [1, 0]
# مریم پوشه را پاک کرد [0, 1]
# امید سالاد را خورد [1, 0]
# مریم پرینتر را پیکربندی کرد [0, 1]

# %%
new_sentence = ["person debugs software ."]

# Parse
new_diagram = parser.sentence2diagram(new_sentence[0])
new_diagram = remove_cups(new_diagram)

# Convert to circuit
new_circuit = ansatz(new_diagram)

# Run through trained model
prediction = model([new_circuit])
print("Raw output:", prediction)

# Get predicted label
predicted_class = np.argmax(prediction, axis=1)[0]
print("Predicted class:", predicted_class)
# Out:
# Raw output: [[0.09943182 0.90056818]]
# Predicted class: 1

# %%
# train_circuits[50].draw(figsize=(9, 9))
# tket_circuit = train_circuits[0].to_tk()
# train_circuits

# from pytket.circuit.display import render_circuit_jupyter, view_browser,render_circuit_as_html

# #render_circuit_jupyter(tket_circuit)
# 
# render_circuit_as_html(tket_circuit)
# train_circuits[0]
train_circuits[0].draw(figsize=(9, 9))
